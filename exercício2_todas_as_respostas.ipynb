# %% [markdown]
# <a href="https://colab.research.google.com/github/nayarapalma/Exerc-cio2/blob/main/exerc%C3%ADcio2_todas_as_respostas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n1 = int(input("Digite o primeiro número: "))
n2 = int(input("Digite o segundo número: "))
n3 = int(input("Digite o terceiro número: "))

print(n1, n2, n3)
# Out:
# Digite o primeiro número: 98
# Digite o segundo número: 63
# Digite o terceiro número: 75
# 98 63 75

# %%
nome1= input("Digite o nome1")
nome2 =input("Digite o nome2")
nome3 =input("Digite o nome3")
nome4 =input("Digite o nome4")
nome5 =input("Digite o nome5")
print(nome1,nome2,nome3,nome4,nome5)
# Out:
# Digite o nome1joao
# Digite o nome2rodrigo
# Digite o nome3carlos
# Digite o nome4mateus
# Digite o nome5pedro
# joao rodrigo carlos mateus pedro

# %%
primeiro = input("Digite seu primeiro nome: ")
sobrenome = input("Digite seu sobrenome: ")

print(f"Olá, {primeiro} {sobrenome}! Seja bem-vindo(a)!")
# Out:
# Digite seu primeiro nome: João
# Digite seu sobrenome: Silva
# Olá, João  Silva! Seja bem-vindo(a)!

# %%
cidade = input("Digite o nome da cidade: ")
uf = input("Digite o estado (UF): ")

print(f"A cidade de {cidade} fica localizada no estado de {uf}.")
# Out:
# Digite o nome da cidade: Feira de Santana
# Digite o estado (UF): Ba
# A cidade de Feira de Santana  fica localizada no estado de Ba.

# %%
ano_nascimento = int(input("Ano de nascimento: "))
ano_atual = int(input("Ano atual: "))

idade = ano_atual - ano_nascimento
print(f"Você tem {idade} anos.")
# Out:
# Ano de nascimento: 2005
# Ano atual: 2025
# Você tem 20 anos.

# %%
nome = input("Nome completo: ")
idade = input("Idade: ")
endereco = input("Endereço: ")
profissao = input("Profissão: ")

print("\nCadastro:")
print(f"Nome: {nome}")
print(f"Idade: {idade}")
print(f"Endereço: {endereco}")
print(f"Profissão: {profissao}")
# Out:
# Nome completo: Nayara Palma de Almeida
# Idade: 20
# Endereço: feira
# Profissão: Atendente
#
# Cadastro:
# Nome: Nayara Palma de Almeida
# Idade: 20
# Endereço: feira
# Profissão: Atendente

# %%
alimento1 = input("Alimento 1: ")
alimento2 = input("Alimento 2: ")
alimento3 = input("Alimento 3: ")

print(f"Você escolheu levar: {alimento1}, {alimento2} e {alimento3} para a ilha.")
# Out:
# Alimento 1: mamo
# Alimento 2: limao
# Alimento 3: casca
# Você escolheu levar: mamo, limao e casca para a ilha.

# %%
nome = input("Nome: ")
produto = input("Produto: ")
quantidade = int(input("Quantidade: "))
preco = float(input("Preço: "))

total = quantidade * preco

print(f"\nCompra realizada por {nome}")
print(f"Produto: {produto}")
print(f"Quantidade: {quantidade}")
print(f"Valor unitário: R$ {preco:.2f}")
print(f"Total: R$ {total:.2f}")
# Out:
# Nome: nay
# Produto: limao
# Quantidade: 8
# Preço: 6
#
# Compra realizada por nay
# Produto: limao
# Quantidade: 8
# Valor unitário: R$ 6.00
# Total: R$ 48.00

# %%
numero = int(input("Número: "))

print("Multiplicação:")
print(f"{numero} × 1 = {numero * 1}")
print(f"{numero} × 2 = {numero * 2}")
print(f"{numero} × 3 = {numero * 3}")
print(f"{numero} × 4 = {numero * 4}")
print(f"{numero} × 5 = {numero * 5}")
print(f"{numero} × 6 = {numero * 6}")
print(f"{numero} × 7 = {numero * 7}")
print(f"{numero} × 8 = {numero * 8}")
print(f"{numero} × 9 = {numero * 9}")
print(f"{numero} × 10 = {numero * 10}")

print("\nDivisão:")
print(f"{numero} ÷ 1 = {numero / 1:.2f}")
print(f"{numero} ÷ 2 = {numero / 2:.2f}")
print(f"{numero} ÷ 3 = {numero / 3:.2f}")
print(f"{numero} ÷ 4 = {numero / 4:.2f}")
print(f"{numero} ÷ 5 = {numero / 5:.2f}")
print(f"{numero} ÷ 6 = {numero / 6:.2f}")
print(f"{numero} ÷ 7 = {numero / 7:.2f}")
print(f"{numero} ÷ 8 = {numero / 8:.2f}")
print(f"{numero} ÷ 9 = {numero / 9:.2f}")
print(f"{numero} ÷ 10 = {numero / 10:.2f}")

print("\nAdição:")
print(f"{numero} + 1 = {numero + 1}")
print(f"{numero} + 2 = {numero + 2}")
print(f"{numero} + 3 = {numero + 3}")
print(f"{numero} + 4 = {numero + 4}")
print(f"{numero} + 5 = {numero + 5}")
print(f"{numero} + 6 = {numero + 6}")
print(f"{numero} + 7 = {numero + 7}")
print(f"{numero} + 8 = {numero + 8}")
print(f"{numero} + 9 = {numero + 9}")
print(f"{numero} + 10 = {numero + 10}")

print("\nSubtração:")
print(f"{numero} - 1 = {numero - 1}")
print(f"{numero} - 2 = {numero - 2}")
print(f"{numero} - 3 = {numero - 3}")
print(f"{numero} - 4 = {numero - 4}")
print(f"{numero} - 5 = {numero - 5}")
print(f"{numero} - 6 = {numero - 6}")
print(f"{numero} - 7 = {numero - 7}")
print(f"{numero} - 8 = {numero - 8}")
print(f"{numero} - 9 = {numero - 9}")
print(f"{numero} - 10 = {numero - 10}")
# Out:
# Número: 8
# Multiplicação:
# 8 × 1 = 8
# 8 × 2 = 16
# 8 × 3 = 24
# 8 × 4 = 32
# 8 × 5 = 40
# 8 × 6 = 48
# 8 × 7 = 56
# 8 × 8 = 64
# 8 × 9 = 72
# 8 × 10 = 80
#
# Divisão:
# 8 ÷ 1 = 8.00
# 8 ÷ 2 = 4.00
# 8 ÷ 3 = 2.67
# 8 ÷ 4 = 2.00
# 8 ÷ 5 = 1.60
# 8 ÷ 6 = 1.33
# 8 ÷ 7 = 1.14
# 8 ÷ 8 = 1.00
# 8 ÷ 9 = 0.89
# 8 ÷ 10 = 0.80
#
# Adição:
# 8 + 1 = 9
# 8 + 2 = 10
# 8 + 3 = 11
# 8 + 4 = 12
# 8 + 5 = 13
# 8 + 6 = 14
# 8 + 7 = 15
# 8 + 8 = 16
# 8 + 9 = 17
# 8 + 10 = 18
#
# Subtração:
# 8 - 1 = 7
# 8 - 2 = 6
# 8 - 3 = 5
# 8 - 4 = 4
# 8 - 5 = 3
# 8 - 6 = 2
# 8 - 7 = 1
# 8 - 8 = 0
# 8 - 9 = -1
# 8 - 10 = -2

# %%
nome = input("Nome: ")
idade = input("Idade: ")
curso = input("Curso: ")
evento = input("Evento: ")

print(f"Confirmado! {nome}, {idade} anos, estudante de {curso}, está inscrito no evento {evento}.")
# Out:
# Nome: Nayara
# Idade: 20
# Curso: T.I
# Evento: Formatura
# Confirmado! Nayara , 20 anos, estudante de T.I, está inscrito no evento Formatura.
